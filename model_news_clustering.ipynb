# %% [markdown]
# ## ***Modelado News-Clustering***

# %%
#!pip install umap-learn==0.5.6

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import plotly.express as px
from umap import UMAP
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score, davies_bouldin_score

url_base = "https://raw.githubusercontent.com/lacamposm/Metodos-Estadisticos/main/data/"

# %%
def silhouette_scorer(estimator, X):
    """
    Calcula el Silhouette Score utilizando la métrica de coseno para evaluar la calidad de los clústeres.

    El Silhouette Score mide cómo de similar es un punto de datos a otros puntos de su mismo clúster en comparación
    con los puntos de otros clústeres. El valor oscila entre -1 y 1, donde un valor más alto indica que los puntos
    están mejor agrupados y más separados de otros clústeres.

    :param estimator: Un modelo de clustering que debe tener un método `predict` para obtener las etiquetas de los
    clústeres de las muestras de `X`.
    :param X: Un array-like o matriz de datos (n_samples, n_features) sobre los cuales se calcularán los clústeres.
    :return: El Silhouette Score para el conjunto de datos `X` y las etiquetas de los clústeres obtenidos del
    `estimator`. Se utiliza la métrica de coseno para calcular las distancias.
    """
    if not hasattr(estimator, "predict"):
        raise ValueError(f"El estimator: {estimator} no tiene metodo 'predict'")

    labels = estimator.predict(X)
    return silhouette_score(X, labels, metric="cosine")


def davies_bouldin_scorer(estimator, X):
    """
    Calcula el índice de Davies-Bouldin para evaluar la calidad de los clústeres.

    El índice de Davies-Bouldin mide la media del cociente entre las distancias intra-clúster e inter-clúster para cada
    clúster. Un valor más bajo del índice indica una mejor formación de los clústeres, ya que minimiza la dispersión
    dentro de los clústeres y maximiza la separación entre ellos.

    :param estimator: Un modelo de clustering que debe tener un método `predict` para obtener las etiquetas de los
    clústeres de las muestras de `X`.
    :param X: Un array-like o matriz de datos (n_samples, n_features) sobre los cuales se calcularán los clústeres.
    :return: El valor negativo del índice de Davies-Bouldin para el conjunto de datos `X` y las etiquetas de los
    clústeres obtenidos del `estimator`. Esto invierte la métrica para que pueda maximizarse en las búsquedas
    de hiperparámetros.
    """
    if not hasattr(estimator, "predict"):
        raise ValueError(f"El estimator: {estimator} no tiene metodo 'predict'")

    labels = estimator.predict(X)
    score = -davies_bouldin_score(X, labels)
    return score

# %%
def transform_dict_best_model(input_dict):
    """
    Transforma un diccionario de parámetros de un modelo en un nuevo formato más estructurado.

    Esta función toma un diccionario que contiene información sobre un modelo, incluyendo un preprocesador, un método
    de reducción de dimensiones y un agrupador (clusterer), junto con sus parámetros específicos. La función reorganiza
    esta información en un formato más accesible y fácil de usar.

    :param input_dict: Un diccionario que contiene los parámetros del modelo. Debe incluir las claves "preprocessor",
    "dim_reduction", y "clusterer", así como pares clave-valor para los parámetros del agrupador y la reducción de
    dimensiones que siguen el formato "clusterer__<param_name>" y "dim_reduction__<param_name>".
    :return: Un nuevo diccionario estructurado que contiene el preprocesador, la reducción de dimensiones, el agrupador,
    y los parámetros asociados a cada uno. La clave de los parámetros de agrupador y    de reducción de dimensiones
    se simplifica eliminando el prefijo correspondiente.
    """
    return {
        "preprocessor": input_dict["preprocessor"],
        "dim_reduction": input_dict["dim_reduction"],
        "clusterer": input_dict["clusterer"],
        "clusterer_params": {
            k.split("__")[-1]: v for k, v in input_dict.items()
            if k.startswith("clusterer__")
        },
        "dim_reduction_params": {
            k.split("__")[-1]: v for k, v in input_dict.items()
            if k.startswith("dim_reduction__")
        }
    }
    

def tsne_plot_2d(df, estimator=None, scorer=None, metric=None):
    """
    Genera un gráfico 2D utilizando t-SNE para visualizar embeddings en un espacio reducido.

    Esta función aplica un preprocesador a un DataFrame, seguido de una reducción de dimensionalidad mediante t-SNE.
    Se pueden visualizar los embeddings resultantes en un gráfico, con la opción de agregar etiquetas de clúster para
    distinguir diferentes grupos en los datos.

    :param df: DataFrame que contiene los datos a visualizar. Cada fila representa una observación y cada columna
    representa una característica o variable.
    :param estimator:
    :param scorer:
    :param metric
    """
    if estimator is not None:
        params_estimator = transform_dict_best_model(estimator.get_params())
        preprocessor = params_estimator.get("preprocessor")
        dim_reduction = params_estimator.get("dim_reduction")
        clusterer = params_estimator.get("clusterer")
        best_score = scorer(estimator, df)

        if isinstance(dim_reduction, PCA):
            pipeline = Pipeline([
                ("preprocessor", preprocessor),
                ("dim_reduction", dim_reduction),
            ])

            normalized_embeddings = pipeline.fit_transform(df)

        else:
            normalized_embeddings = preprocessor.fit_transform(df)

        tsne = TSNE(n_components=2, random_state=42, metric=metric)
        df_plot = pd.DataFrame(tsne.fit_transform(normalized_embeddings), columns=["tSNE1", "tSNE2"])
        df_plot["cluster"] = estimator.predict(df) + 1
        df_plot = df_plot.sort_values(by=["cluster"])
        df_plot["cluster"] = df_plot["cluster"].astype("string")
        title = (
            f"""<b>Clustering: News-Summary-Embeddings in Low dimension with t-SNE</b><br>"""
            f"""<span style='font-size: 11px;'>Scaler: {preprocessor.__class__.__name__}, """
            f"""Dim-Reduction: {dim_reduction.__class__.__name__}, Estimator: {clusterer.__class__.__name__}, Metric """
            f"""Plot: {metric}, Scorer Metric: {scorer.__name__}={best_score:.3f}</span>"""
        )
        color = "cluster"

    else:
        df_scaled = StandardScaler().fit_transform(df)
        tsne = TSNE(n_components=2, random_state=42, metric=metric)
        df_plot = pd.DataFrame(tsne.fit_transform(df_scaled), columns=["tSNE1", "tSNE2"])
        title = (
            f"""<b>News-Summary-Embeddings in Low dimension with t-SNE</b><br>"""
            f"""<span style='font-size: 10px;'>Scaler: {StandardScaler().__class__.__name__}"""
        )
        color = None

    (
        px.scatter(
            df_plot, x="tSNE1", y="tSNE2", color=color,
            title=title,
            opacity=0.8,
            color_discrete_sequence=px.colors.qualitative.Dark24,
            template="plotly_white"
        )
        .update_traces(marker=dict(size=3))
        .show()
    )
    

def umap_plot_2d(df, estimator=None, scorer=None, metric=None):
    """
    Función que genera un gráfico en 2D utilizando UMAP y muestra los clústeres.

    :param df: pd.DataFrame con los embeddings de los resumenes de las noticias).
    :param estimator:
    :param scorer:
    :param metric
    """
    if estimator is not None:
        params_estimator = transform_dict_best_model(estimator.get_params())
        preprocessor = params_estimator.get("preprocessor")
        dim_reduction = params_estimator.get("dim_reduction")
        clusterer = params_estimator.get("clusterer")
        best_score = scorer(estimator, df)

        if isinstance(dim_reduction, UMAP):
            df_scaled = preprocessor.fit_transform(df)
            dim_reduction.n_components = 2
            df_plot = pd.DataFrame(dim_reduction.fit_transform(df_scaled), columns=["UMAP1", "UMAP2"])
        else:
            pipeline = Pipeline([
                ("preprocessor", preprocessor),
                ("dim_reduction", dim_reduction),
            ])
            df_scaled = pipeline.fit_transform(df)
            reducer = UMAP(n_components=2, random_state=42, metric=metric)
            df_plot = pd.DataFrame(reducer.fit_transform(df_scaled), columns=["UMAP1", "UMAP2"])

        df_plot["cluster"] = estimator.predict(df) + 1
        df_plot = df_plot.sort_values(by=["cluster"])
        df_plot["cluster"] = df_plot["cluster"].astype("string")
        color = "cluster"
        title = (
            f"""<b>Clustering: News-Summary-Embeddings in Low dimension with UMAP</b><br>"""
            f"""<span style='font-size: 11px;'>Scaler: {preprocessor.__class__.__name__}, """
            f"""Dim-Reduction: {dim_reduction.__class__.__name__}, Estimator: {clusterer.__class__.__name__}, Metric:"""
            f""" {metric}, Scorer Metric: {scorer.__name__}={best_score:.3f}</span>"""

        )

    else:
        df_scaled = StandardScaler().fit_transform(df)
        reducer = UMAP(n_components=2, random_state=42)
        df_plot = pd.DataFrame(reducer.fit_transform(df_scaled), columns=["UMAP1", "UMAP2"])
        title = (
            f"""<b>News-Summary-Embeddings in Low dimension with UMAP</b><br>"""
            f"""<span style='font-size: 10px;'>Scaler: {StandardScaler().__class__.__name__}"""
        )
        color = None

    (
        px.scatter(
            df_plot, x="UMAP1", y="UMAP2", color=color,
            title=title,
            opacity=0.8,
            color_discrete_sequence=px.colors.qualitative.Dark24,
            template="plotly_white"
        )
        .update_traces(marker=dict(size=3))
        .show()
    )

# %%
n_iter = 10                                     # Número de ajustes en RandomizedSearchCV.
scorers = ["silhouette", "davies-bouldin"]      # Puedes seleccionar diferentes metrica de adecuación de clusters
random_state = 42                               # Semilla aletoria de RandomizedSearchCV para replicar resultados.


scoring_dict = {
    "silhouette": silhouette_scorer,
    "davies-bouldin": davies_bouldin_scorer,
}


list_scalers = [StandardScaler(), MinMaxScaler(), RobustScaler()]

pca_n_components = [num for num in range(5, 80)]
umap_metrics = ["cosine", "correlation"]
umap_n_neighbors = [5, 10, 15]
umap_min_dist = [0.1, 0.3, 0.5]
umap_n_components = [2, 3, 4]

gauss_mix_n_components = [num for num in range(5, 13)]
gauss_mix_covariance_type = ["full", "diag"]
kmeans_n_clusters = [num for num in range(5, 21)]

param_grid = [
    {
        "preprocessor": list_scalers,
        "dim_reduction": [PCA()],
        "dim_reduction__n_components": pca_n_components,
        "clusterer": [KMeans()],
        "clusterer__n_clusters": kmeans_n_clusters,
    },
    {
        "preprocessor": list_scalers,
        "dim_reduction": [PCA()],
        "dim_reduction__n_components": pca_n_components,
        "clusterer": [GaussianMixture()],
        "clusterer__n_components": gauss_mix_n_components,
        "clusterer__covariance_type": gauss_mix_covariance_type
    },
    {
        "preprocessor": list_scalers,
        "dim_reduction": [UMAP()],
        "dim_reduction__n_neighbors": umap_n_neighbors,
        "dim_reduction__min_dist": umap_min_dist,
        "dim_reduction__n_components": umap_n_components,
        "dim_reduction__metric": umap_metrics,
        "clusterer": [KMeans()],
        "clusterer__n_clusters": kmeans_n_clusters,
    },
    {
        "preprocessor": list_scalers,
        "dim_reduction": [UMAP()],
        "dim_reduction__n_neighbors": umap_n_neighbors,
        "dim_reduction__min_dist": umap_min_dist,
        "dim_reduction__n_components": umap_n_components,
        "dim_reduction__metric": umap_metrics,
        "clusterer": [GaussianMixture()],
        "clusterer__n_components": gauss_mix_n_components,
        "clusterer__covariance_type": gauss_mix_covariance_type
    }
]


pipeline = Pipeline([
        ("preprocessor", "passthrough"),
        ("dim_reduction", "passthrough"),
        ("clusterer", "passthrough")
    ])

random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_grid,
    scoring=scoring_dict,
    cv=2,
    n_jobs=-1,
    verbose=3,
    n_iter=n_iter,
    refit="silhouette",
    random_state=random_state
)

# %%
df_embed = pd.read_parquet(url_base + "data/mxbai-embed-large_summary_news_el_tiempo.parquet")
df_embed
# Out:
#                                                         0         1     \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev... -0.020917 -0.006987
# https://www.eltiempo.com/bogota/vehiculo-se-inc... -0.031880  0.027921
# https://www.eltiempo.com/mundo/eeuu-y-canada/es... -0.021267  0.007155
# https://www.eltiempo.com/mundo/europa/morire-en... -0.001724 -0.011231
# https://www.eltiempo.com/colombia/otras-ciudade... -0.015240  0.014905
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.015249  0.032793
# https://www.eltiempo.com/mundo/medio-oriente/as... -0.013496 -0.014557
# https://www.eltiempo.com/mas-contenido/del-crud... -0.024780  0.041507
# https://www.eltiempo.com/mas-contenido/el-impon... -0.013511  0.009672
# https://www.eltiempo.com/mas-contenido/los-trin...  0.015330  0.010940
#
#                                                         2         3     \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev... -0.026591  0.017555
# https://www.eltiempo.com/bogota/vehiculo-se-inc... -0.016712  0.032918
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...  0.034475  0.030611
# https://www.eltiempo.com/mundo/europa/morire-en...  0.006536  0.007330
# https://www.eltiempo.com/colombia/otras-ciudade...  0.014017  0.032451
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.022702  0.048635
# https://www.eltiempo.com/mundo/medio-oriente/as... -0.018691  0.047176
# https://www.eltiempo.com/mas-contenido/del-crud...  0.002410  0.001920
# https://www.eltiempo.com/mas-contenido/el-impon... -0.010728  0.041266
# https://www.eltiempo.com/mas-contenido/los-trin...  0.012188 -0.021195
#
#                                                         4         5     \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev...  0.032127 -0.046068
# https://www.eltiempo.com/bogota/vehiculo-se-inc...  0.024373 -0.010680
# https://www.eltiempo.com/mundo/eeuu-y-canada/es... -0.008942 -0.016378
# https://www.eltiempo.com/mundo/europa/morire-en...  0.013462 -0.022181
# https://www.eltiempo.com/colombia/otras-ciudade...  0.006244 -0.013349
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.002823 -0.039297
# https://www.eltiempo.com/mundo/medio-oriente/as...  0.018366 -0.011003
# https://www.eltiempo.com/mas-contenido/del-crud... -0.007972  0.006983
# https://www.eltiempo.com/mas-contenido/el-impon...  0.003864  0.014097
# https://www.eltiempo.com/mas-contenido/los-trin...  0.031553 -0.026548
#
#                                                         6         7     \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev... -0.048087  0.004656
# https://www.eltiempo.com/bogota/vehiculo-se-inc... -0.058477 -0.027742
# https://www.eltiempo.com/mundo/eeuu-y-canada/es... -0.011049 -0.016557
# https://www.eltiempo.com/mundo/europa/morire-en... -0.013968  0.002475
# https://www.eltiempo.com/colombia/otras-ciudade... -0.052630  0.047903
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.053139  0.034664
# https://www.eltiempo.com/mundo/medio-oriente/as... -0.093697  0.026669
# https://www.eltiempo.com/mas-contenido/del-crud... -0.026574  0.025248
# https://www.eltiempo.com/mas-contenido/el-impon... -0.032700  0.034680
# https://www.eltiempo.com/mas-contenido/los-trin... -0.064843  0.015146
#
#                                                         8         9     ...  \
# url_page                                                                ...
# https://www.eltiempo.com/mundo/latinoamerica/ev...  0.005598  0.049441  ...
# https://www.eltiempo.com/bogota/vehiculo-se-inc...  0.044773  0.041911  ...
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...  0.039848  0.030022  ...
# https://www.eltiempo.com/mundo/europa/morire-en...  0.010086  0.029852  ...
# https://www.eltiempo.com/colombia/otras-ciudade...  0.035785  0.030179  ...
# ...                                                      ...       ...  ...
# https://www.eltiempo.com/mas-contenido/el-llama...  0.032758  0.025721  ...
# https://www.eltiempo.com/mundo/medio-oriente/as... -0.002839 -0.000249  ...
# https://www.eltiempo.com/mas-contenido/del-crud...  0.020038  0.037295  ...
# https://www.eltiempo.com/mas-contenido/el-impon...  0.065962  0.033704  ...
# https://www.eltiempo.com/mas-contenido/los-trin...  0.036667 -0.002814  ...
#
#                                                         1014      1015  \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev...  0.028381  0.019583
# https://www.eltiempo.com/bogota/vehiculo-se-inc...  0.048250  0.040552
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...  0.073989  0.016037
# https://www.eltiempo.com/mundo/europa/morire-en...  0.043627  0.040211
# https://www.eltiempo.com/colombia/otras-ciudade... -0.000029  0.047785
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama...  0.027468  0.045833
# https://www.eltiempo.com/mundo/medio-oriente/as...  0.032180 -0.000164
# https://www.eltiempo.com/mas-contenido/del-crud...  0.042184  0.043891
# https://www.eltiempo.com/mas-contenido/el-impon...  0.052577  0.008840
# https://www.eltiempo.com/mas-contenido/los-trin...  0.026943  0.041879
#
#                                                         1016      1017  \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev...  0.007692  0.002656
# https://www.eltiempo.com/bogota/vehiculo-se-inc... -0.037708  0.000493
# https://www.eltiempo.com/mundo/eeuu-y-canada/es... -0.018351 -0.029923
# https://www.eltiempo.com/mundo/europa/morire-en... -0.020006  0.009449
# https://www.eltiempo.com/colombia/otras-ciudade... -0.012244 -0.007176
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.016872 -0.021523
# https://www.eltiempo.com/mundo/medio-oriente/as... -0.033964 -0.035739
# https://www.eltiempo.com/mas-contenido/del-crud... -0.024159 -0.011424
# https://www.eltiempo.com/mas-contenido/el-impon...  0.002960  0.019802
# https://www.eltiempo.com/mas-contenido/los-trin...  0.021138 -0.025357
#
#                                                         1018      1019  \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev...  0.050690  0.041930
# https://www.eltiempo.com/bogota/vehiculo-se-inc...  0.010013  0.003768
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...  0.037829 -0.002450
# https://www.eltiempo.com/mundo/europa/morire-en...  0.054445  0.034426
# https://www.eltiempo.com/colombia/otras-ciudade...  0.010913  0.012925
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama...  0.025576  0.014999
# https://www.eltiempo.com/mundo/medio-oriente/as...  0.008483  0.055563
# https://www.eltiempo.com/mas-contenido/del-crud...  0.054588 -0.006380
# https://www.eltiempo.com/mas-contenido/el-impon...  0.011811  0.018858
# https://www.eltiempo.com/mas-contenido/los-trin...  0.017482  0.026049
#
#                                                         1020      1021  \
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev...  0.001792 -0.013605
# https://www.eltiempo.com/bogota/vehiculo-se-inc...  0.026349  0.010262
# https://www.eltiempo.com/mundo/eeuu-y-canada/es... -0.024424  0.009189
# https://www.eltiempo.com/mundo/europa/morire-en... -0.022466 -0.010860
# https://www.eltiempo.com/colombia/otras-ciudade...  0.016821  0.001564
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.008812 -0.021739
# https://www.eltiempo.com/mundo/medio-oriente/as... -0.048210 -0.003561
# https://www.eltiempo.com/mas-contenido/del-crud...  0.002650 -0.021769
# https://www.eltiempo.com/mas-contenido/el-impon... -0.007259 -0.019385
# https://www.eltiempo.com/mas-contenido/los-trin... -0.008655 -0.007465
#
#                                                         1022      1023
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev... -0.002610 -0.016743
# https://www.eltiempo.com/bogota/vehiculo-se-inc... -0.003502  0.014081
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...  0.001148 -0.009378
# https://www.eltiempo.com/mundo/europa/morire-en... -0.025343 -0.013328
# https://www.eltiempo.com/colombia/otras-ciudade... -0.004066  0.014183
# ...                                                      ...       ...
# https://www.eltiempo.com/mas-contenido/el-llama... -0.010349  0.009338
# https://www.eltiempo.com/mundo/medio-oriente/as...  0.001201 -0.018963
# https://www.eltiempo.com/mas-contenido/del-crud... -0.050148  0.003720
# https://www.eltiempo.com/mas-contenido/el-impon... -0.031452  0.014297
# https://www.eltiempo.com/mas-contenido/los-trin... -0.008995  0.012198
#
# [3551 rows x 1024 columns]

# %%
tsne_plot_2d(df_embed, metric="cosine")
umap_plot_2d(df_embed, metric="cosine")

# %%
best_model = random_search.fit(df_embed)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=full, clusterer__n_components=12, dim_reduction=PCA(), dim_reduction__n_components=10, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.612) silhouette: (test=0.101) total time=   3.5s
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=full, clusterer__n_components=12, dim_reduction=PCA(), dim_reduction__n_components=10, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.754) silhouette: (test=0.067) total time=   4.1s
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=6, dim_reduction=PCA(), dim_reduction__n_components=41, preprocessor=MinMaxScaler(); davies-bouldin: (test=-2.578) silhouette: (test=0.015) total time=   3.8s
# [CV 1/2] END clusterer=KMeans(), clusterer__n_clusters=7, dim_reduction=PCA(), dim_reduction__n_components=10, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.536) silhouette: (test=0.096) total time=   2.6s
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=6, dim_reduction=PCA(), dim_reduction__n_components=41, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.503) silhouette: (test=0.067) total time=   4.3s
# [CV 1/2] END clusterer=KMeans(), clusterer__n_clusters=8, dim_reduction=PCA(), dim_reduction__n_components=66, preprocessor=RobustScaler(); davies-bouldin: (test=-3.406) silhouette: (test=0.108) total time=   5.5s
# [CV 2/2] END clusterer=KMeans(), clusterer__n_clusters=8, dim_reduction=PCA(), dim_reduction__n_components=66, preprocessor=RobustScaler(); davies-bouldin: (test=-3.508) silhouette: (test=0.083) total time=   4.8s
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=8, dim_reduction=PCA(), dim_reduction__n_components=68, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.613) silhouette: (test=0.058) total time=   4.4s
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=8, dim_reduction=PCA(), dim_reduction__n_components=68, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.139) silhouette: (test=-0.032) total time=   4.3s
# [CV 2/2] END clusterer=KMeans(), clusterer__n_clusters=7, dim_reduction=PCA(), dim_reduction__n_components=10, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.484) silhouette: (test=0.088) total time=   2.7s
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=full, clusterer__n_components=12, dim_reduction=PCA(), dim_reduction__n_components=76, preprocessor=RobustScaler(); davies-bouldin: (test=-3.681) silhouette: (test=0.063) total time=   7.1s
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=full, clusterer__n_components=12, dim_reduction=PCA(), dim_reduction__n_components=76, preprocessor=RobustScaler(); davies-bouldin: (test=-3.844) silhouette: (test=0.044) total time=   8.4s
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=full, clusterer__n_components=8, dim_reduction=PCA(), dim_reduction__n_components=55, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.502) silhouette: (test=0.077) total time=   4.3s
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=full, clusterer__n_components=8, dim_reduction=PCA(), dim_reduction__n_components=55, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.418) silhouette: (test=0.065) total time=   4.1s
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=6, dim_reduction=UMAP(), dim_reduction__metric=cosine, dim_reduction__min_dist=0.3, dim_reduction__n_components=2, dim_reduction__n_neighbors=15, preprocessor=MinMaxScaler(); davies-bouldin: (test=-4.214) silhouette: (test=0.068) total time= 2.2min
# [CV 2/2] END clusterer=KMeans(), clusterer__n_clusters=5, dim_reduction=UMAP(), dim_reduction__metric=cosine, dim_reduction__min_dist=0.5, dim_reduction__n_components=3, dim_reduction__n_neighbors=15, preprocessor=MinMaxScaler(); davies-bouldin: (test=-4.407) silhouette: (test=0.064) total time= 2.2min
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=6, dim_reduction=UMAP(), dim_reduction__metric=cosine, dim_reduction__min_dist=0.3, dim_reduction__n_components=2, dim_reduction__n_neighbors=15, preprocessor=MinMaxScaler(); davies-bouldin: (test=-4.075) silhouette: (test=0.075) total time= 2.2min
# [CV 1/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=10, dim_reduction=UMAP(), dim_reduction__metric=cosine, dim_reduction__min_dist=0.5, dim_reduction__n_components=3, dim_reduction__n_neighbors=10, preprocessor=StandardScaler(); davies-bouldin: (test=-3.415) silhouette: (test=0.090) total time= 2.2min
# [CV 2/2] END clusterer=GaussianMixture(), clusterer__covariance_type=diag, clusterer__n_components=10, dim_reduction=UMAP(), dim_reduction__metric=cosine, dim_reduction__min_dist=0.5, dim_reduction__n_components=3, dim_reduction__n_neighbors=10, preprocessor=StandardScaler(); davies-bouldin: (test=-3.701) silhouette: (test=0.059) total time= 2.3min
# [CV 1/2] END clusterer=KMeans(), clusterer__n_clusters=5, dim_reduction=UMAP(), dim_reduction__metric=cosine, dim_reduction__min_dist=0.5, dim_reduction__n_components=3, dim_reduction__n_neighbors=15, preprocessor=MinMaxScaler(); davies-bouldin: (test=-3.843) silhouette: (test=0.084) total time= 2.3min

# %%
best_model.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor', RobustScaler()),
#                 ('dim_reduction', PCA(n_components=66)),
#                 ('clusterer', KMeans())])

# %%
pd.DataFrame(best_model.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      51.271346      0.385825        83.826072        1.606028
# 1       3.238220      0.020554         1.920007        0.366278
# 2       6.458471      0.466380         1.315097        0.194458
# 3       2.099224      0.281909         1.695740        0.037647
# 4      50.825454      0.182033        84.383456        0.540410
# 5      50.813658      0.393914        82.270513        0.918374
# 6       2.208401      0.224756         1.821031        0.052197
# 7       2.459212      0.280470         1.900168        0.350558
# 8       1.343566      0.007296         1.300343        0.023179
# 9       3.110874      0.014511         1.114237        0.074930
#
#   param_preprocessor  param_dim_reduction__n_neighbors  \
# 0     MinMaxScaler()                              15.0
# 1     RobustScaler()                               NaN
# 2     RobustScaler()                               NaN
# 3     MinMaxScaler()                               NaN
# 4   StandardScaler()                              10.0
# 5     MinMaxScaler()                              15.0
# 6     MinMaxScaler()                               NaN
# 7     MinMaxScaler()                               NaN
# 8     MinMaxScaler()                               NaN
# 9     MinMaxScaler()                               NaN
#
#    param_dim_reduction__n_components  param_dim_reduction__min_dist  \
# 0                                  3                            0.5
# 1                                 66                            NaN
# 2                                 76                            NaN
# 3                                 10                            NaN
# 4                                  3                            0.5
# 5                                  2                            0.3
# 6                                 41                            NaN
# 7                                 68                            NaN
# 8                                 10                            NaN
# 9                                 55                            NaN
#
#   param_dim_reduction__metric param_dim_reduction  ...  \
# 0                      cosine              UMAP()  ...
# 1                         NaN               PCA()  ...
# 2                         NaN               PCA()  ...
# 3                         NaN               PCA()  ...
# 4                      cosine              UMAP()  ...
# 5                      cosine              UMAP()  ...
# 6                         NaN               PCA()  ...
# 7                         NaN               PCA()  ...
# 8                         NaN               PCA()  ...
# 9                         NaN               PCA()  ...
#
#    split0_test_silhouette split1_test_silhouette  mean_test_silhouette  \
# 0                0.083918               0.064168              0.074043
# 1                0.108217               0.083052              0.095634
# 2                0.063357               0.043610              0.053483
# 3                0.100876               0.066659              0.083768
# 4                0.090422               0.059237              0.074829
# 5                0.075420               0.068490              0.071955
# 6                0.067496               0.015345              0.041420
# 7                0.058030              -0.031904              0.013063
# 8                0.095963               0.087849              0.091906
# 9                0.076880               0.064583              0.070732
#
#   std_test_silhouette rank_test_silhouette  split0_test_davies-bouldin  \
# 0            0.009875                    5                   -3.842623
# 1            0.012583                    1                   -3.406415
# 2            0.009873                    8                   -3.680987
# 3            0.017109                    3                   -3.612422
# 4            0.015593                    4                   -3.415275
# 5            0.003465                    6                   -4.075437
# 6            0.026075                    9                   -3.503485
# 7            0.044967                   10                   -3.612718
# 8            0.004057                    2                   -3.535716
# 9            0.006148                    7                   -3.501990
#
#    split1_test_davies-bouldin  mean_test_davies-bouldin  \
# 0                   -4.406712                 -4.124667
# 1                   -3.508425                 -3.457420
# 2                   -3.843990                 -3.762489
# 3                   -3.754184                 -3.683303
# 4                   -3.700893                 -3.558084
# 5                   -4.213783                 -4.144610
# 6                   -2.578498                 -3.040991
# 7                   -3.139329                 -3.376024
# 8                   -3.483836                 -3.509776
# 9                   -3.418062                 -3.460026
#
#    std_test_davies-bouldin  rank_test_davies-bouldin
# 0                 0.282045                         9
# 1                 0.051005                         3
# 2                 0.081502                         8
# 3                 0.070881                         7
# 4                 0.142809                         6
# 5                 0.069173                        10
# 6                 0.462494                         1
# 7                 0.236694                         2
# 8                 0.025940                         5
# 9                 0.041964                         4
#
# [10 rows x 25 columns]

# %%
labels = best_model.predict(df_embed)
labels
# Out:
# array([0, 6, 3, ..., 1, 1, 2], dtype=int32)

# %%
tsne_plot_2d(df_embed, best_model.best_estimator_, silhouette_scorer, "cosine")
umap_plot_2d(df_embed, best_model.best_estimator_, silhouette_scorer, "cosine")

# %%
pd.DataFrame(best_model.predict(df_embed) + 1, index=df_embed.index, columns=["cluster"])
# Out:
#                                                     cluster
# url_page
# https://www.eltiempo.com/mundo/latinoamerica/ev...        1
# https://www.eltiempo.com/bogota/vehiculo-se-inc...        7
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...        4
# https://www.eltiempo.com/mundo/europa/morire-en...        3
# https://www.eltiempo.com/colombia/otras-ciudade...        7
# ...                                                     ...
# https://www.eltiempo.com/mas-contenido/el-llama...        2
# https://www.eltiempo.com/mundo/medio-oriente/as...        6
# https://www.eltiempo.com/mas-contenido/del-crud...        2
# https://www.eltiempo.com/mas-contenido/el-impon...        2
# https://www.eltiempo.com/mas-contenido/los-trin...        3
#
# [3551 rows x 1 columns]

# %% [markdown]
# ### ***Caracterizacion de los clusters***

# %%
import json
import pandas as pd

with open(url_base + "octubre_news_summary.json", "r") as archivo:
    datos_json = json.load(archivo)


df_predict = pd.DataFrame(best_model.predict(df_embed) +1, index=df_embed.index, columns=["cluster"])
df_summary = pd.DataFrame(data=datos_json.values(), index=datos_json.keys(), columns=["summary"])
df_review = df_predict.merge(df_summary, left_index=True, right_index=True)
df_review
# Out:
#                                                     cluster  \
# https://www.eltiempo.com/mundo/latinoamerica/ev...        1
# https://www.eltiempo.com/bogota/vehiculo-se-inc...        7
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...        4
# https://www.eltiempo.com/mundo/europa/morire-en...        3
# https://www.eltiempo.com/colombia/otras-ciudade...        7
# ...                                                     ...
# https://www.eltiempo.com/mas-contenido/el-llama...        2
# https://www.eltiempo.com/mundo/medio-oriente/as...        6
# https://www.eltiempo.com/mas-contenido/del-crud...        2
# https://www.eltiempo.com/mas-contenido/el-impon...        2
# https://www.eltiempo.com/mas-contenido/los-trin...        3
#
#                                                                                               summary
# https://www.eltiempo.com/mundo/latinoamerica/ev...  Evo Morales, expresidente de Bolivia, amenaza ...
# https://www.eltiempo.com/bogota/vehiculo-se-inc...  El Cuerpo de Bomberos de Cundinamarca atendió ...
# https://www.eltiempo.com/mundo/eeuu-y-canada/es...  Los accidentes automovilísticos están en aumen...
# https://www.eltiempo.com/mundo/europa/morire-en...  Alexei Navalni, opositor ruso al presidente Vl...
# https://www.eltiempo.com/colombia/otras-ciudade...  Un fuerte vendaval sorprendió a los habitantes...
# ...                                                                                               ...
# https://www.eltiempo.com/mas-contenido/el-llama...  El acuerdo de paz con las Farc ha permitido la...
# https://www.eltiempo.com/mundo/medio-oriente/as...  El viernes, un bombardeo aéreo israelí eliminó...
# https://www.eltiempo.com/mas-contenido/del-crud...  El tema central es la transición energética en...
# https://www.eltiempo.com/mas-contenido/el-impon...  El Meta enfrenta la amenaza de deforestación, ...
# https://www.eltiempo.com/mas-contenido/los-trin...  El Topo Solano y José David Oropeza son dos de...
#
# [3551 rows x 2 columns]

# %%
def get_text_sample_by_cluster(label_cluster, size_sample):
    """
    """
    df = df_review.query("cluster == @label_cluster").sample(size_sample)
    text_to_llm = df["summary"].to_list()
    text_to_llm = text_to_llm = "\n".join([f"Noticia {i+1}\n{news}\n" for i, news in enumerate(text_to_llm)])
    print(text_to_llm)
    return text_to_llm

print(get_text_sample_by_cluster(2, 30))
# Out:
# Noticia 1
# El número de internautas en el mundo ha continuado creciendo desde 2005, con un incremento significativo durante la pandemia, especialmente en Colombia donde se espera alcanzar 44 millones en cinco años. Las redes sociales como Facebook y plataformas locales como Chat Bogota han facilitado la interacción entre ciudadanos de diferentes países. En América Latina, Brasil y México son líderes en valorar el socializar libremente. Moderadores en chats online garantizan una experiencia positiva, revisando y eliminando contenido inapropiado. Salas específicas para ciudades como Bogotá permiten a los usuarios conectarse con personas de su mismo país y ciudad, potenciando la posibilidad de encuentros presenciales.
#
# Noticia 2
# El jueves 3 de octubre, la Imprensa Nacional Casa da Moeda de Portugal visitó las instalaciones de la Imprenta Nacional en Colombia tras firmar un memorando de entendimiento para cooperar en la producción y personalización de pasaportes. El acuerdo permitirá a Portugal producir libretas de pasaporte durante 10 años, tras lo cual donará la infraestructura al gobierno colombiano. La Cancillería destaca la experiencia portuguesa en este ámbito, mientras que el modelo incluye capacitación y transferencia de conocimientos para asumir la producción local a partir de septiembre de 2025.
#
# Noticia 3
# El lunes 7 de octubre de 2024, Enel Colombia realizará trabajos de mantenimiento en redes eléctricas que causarán cortes de luz en varios barrios de Bogotá. Los residentes de Fontibón, Teusaquillo, Suba, Usaquén, Ciudad Bolívar, Kennedy, Puente Aranda y Santa Fe se preparan para interrupciones programadas desde las 8 a.m. hasta las 5:30 p.m., afectando áreas específicas en cada barrio. Estos cortes podrían impactar el servicio de agua y drenaje en algunas zonas, y la Alcaldía recomienda a los residentes prepararse con anticipación.
#
# Noticia 4
# La restricción de pico y placa en Bucaramanga sigue vigente, afectando vehículos particulares, motocicletas y taxis. Los automóviles con placas terminadas en 5 o 6 no pueden circular entre las 6:00 a. m. y 8:00 p. m., mientras que los taxis con placas terminadas en 3 o 4 deben evitar el tráfico de 7:00 a. m. a 9:00 p. m. La medida busca reducir la congestión vehicular y mejorar la movilidad, aunque incurre en multas quienes no cumplan.
#
# Noticia 12
# El Banco Mundial ha revisado sus proyecciones de crecimiento económico para Colombia y América Latina. Para 2024, espera un crecimiento del 1,5%, un aumento de 0,2 puntos porcentuales respecto a junio. Sin embargo, para 2025 y 2026, las estimaciones se han reducido. El Banco Mundial atribuye estos bajos pronósticos a obstáculos estructurales y desigualdad persistente en la región. La organización sugiere que los países deben aprovechar el impulso actual para implementar reformas estructurales que fomenten el crecimiento sostenible, como modernizar sistemas tributarios y recaudatorios.
#
# Noticia 13
# El proceso para obtener pasaportes en Colombia ha cambiado a partir del 3 de octubre, permitiendo la renovación y expedición por vía virtual. La Imprenta Nacional transicionará con Thomas Greg & Sons hasta septiembre de 2025. El costo disminuirá a $180.000 en Bogotá, mientras que en otros países será de 60 euros o 82 dólares. Algunos grupos, como personas del Sisbén niveles 1 y 2, podrán obtenerlo gratis si cumplen con ciertos requisitos.
#
# Noticia 14
# La Empresa de Acueducto y Alcantarillado de Bogotá (EAAB) ha anunciado un nuevo turno de racionamiento de agua para el 2 de octubre en varios sectores de Bogotá y sus alrededores, afectando principalmente a barrios como Bosa, Ciudad Bolívar, Kennedy, Puente Aranda y Tunjuelito. Esta medida busca preservar los niveles de los embalses que abastecen la ciudad para garantizar el suministro sostenible tanto en Bogotá como en las poblaciones vecinas. La EAAB ha compartido recomendaciones para un uso responsable del agua durante estos días.
#
# Las implicaciones a corto plazo incluyen restricciones significativas en el consumo de agua en los barrios afectados, lo que puede impactar en la vida cotidiana y servicios básicos. A largo plazo, se espera mejorar la eficiencia en el uso del recurso hídrico y asegurar la sostenibilidad del suministro.
#
# Noticia 15
# El sexto ciclo de negociaciones entre el Gobierno y las disidencias de las Farc-EP, lideradas por Calarcá, tiene fecha definida para esta semana en Bogotá. Camilo González Posso, jefe de la delegación gubernamental, confirmó que la plenaria se realizará después de reuniones preliminares con los bloques involucrados. Se discute la posibilidad de extender el cese del fuego hasta el 15 de octubre y el papel de Rafaela Cortés, gobernadora del Meta, como facilitadora en el proceso. Las conversaciones buscan avanzar hacia acuerdos que beneficien a las comunidades y se evalúa la situación de enfrentamientos violentos en zonas afectadas.
#
# Noticia 16
# El inicio de octubre en Bogotá ha estado caracterizado por bajas temperaturas y neblina, lo cual podría afectar el tráfico aéreo. La Aeronáutica Civil advirtió que estas condiciones podrían causar demoras en los vuelos del Aeropuerto El Dorado. Además, 116 colombianos repatriados desde Líbano aún no han llegado debido a las mismas condiciones climáticas que están retrasando el itinerario de su vuelo.
#
# Noticia 17
# El Servicio Administrativo de Identificación, Migración y Extranjería de Venezuela (Saime) informó que ciudadanos que tramitaron pasaportes en consulados cerrados deben recogerlos en Caracas. Latam Colombia anunció que rechazará a pasajeros venezolanos con pasaporte vencido, obligándolos a obtener un "Documento de Viaje" o viajar con doble nacionalidad. Estas medidas podrían afectar la movilidad y los trámites de miles de venezolanos en el exterior.
#
# Noticia 18
#
# Noticia 25
# El Ministerio de Comercio, Industria y Turismo impuso una salvaguardia a las importaciones de barras de hierro o acero corrugadas desde Bolivia, Ecuador y Perú, estableciendo un cupo anual de 29.529 toneladas con un arancel del 14,5% para excedentes. La medida, recomendada por el Comité Triple A, responde a una investigación que demostró daño a la industria siderúrgica colombiana. El ministro Luis Carlos Reyes aseguró que se busca una relación comercial justa y equilibrada. Las importaciones desde Perú representan casi el 100% del total en este sector.
#
# Noticia 26
# El Ministerio de Relaciones Exteriores de Colombia prepara la 'Visa v', un nuevo tipo de visa para regularizar a ciudadanos venezolanos ilegales en el país. Este visado, con una duración de dos años, permitirá trabajar y estudiar bajo ciertas condiciones. El documento busca ser una herramienta transitoria mientras se desarrollan otras políticas migratorias. La Visa 'V' solo será otorgada a venezolanos que ingresaron antes de la publicación de la resolución y cumplen con los requisitos necesarios, incluyendo antecedentes judiciales limpios.
#
# Noticia 27
# La reinita rayada (Setophaga striata), una pequeña ave migratoria, realiza un viaje épico de hasta 3 días cruzando el océano Atlántico desde Norteamérica a Sudamérica. En los últimos 10 años, sus poblaciones han disminuido drásticamente, poniéndola en riesgo de entrar en la lista de especies amenazadas. La docente Andrea Morales Rozo, de la UNAL Sede Amazonia, investigó su hábitat y encontró que factores climáticos y deforestación afectan su supervivencia. Morales sugiere conservar sistemas agroforestales y fragmentos de bosque para ayudar a su conservación.
#
# Noticia 28
# Valery Bujato, una creadora de contenido colombiana radicada en Estados Unidos, comparte su experiencia diaria como influencer y sus videos sobre misterios y rutina. Juan Giraldo, otro creador de contenido colombiano en Boston, ofrece consejos sobre vida crediticia y aprendizaje del inglés. Ambos destacan la soledad y el desafío de adaptarse a un nuevo país, mientras buscan prosperar en el mundo digital.
#
# Noticia 29
# Xiaomi ha lanzado en Colombia su nueva Serie Xiaomi 14T, que incluye dos dispositivos con cámaras de alta calidad y lentes profesionales de Leica. Estos smartphones ofrecen una experiencia visual impresionante y funciones avanzadas como el modo película y la inteligencia artificial para mejorar la productividad y la creatividad. El Xiaomi 14T Pro estará disponible a partir del 10 de octubre por $3'499.900, mientras que el Xiaomi 14T costará $2'799.900. Ambos modelos incluyen baterías de alta capacidad y tecnologías de carga rápida.
#
# Noticia 30
# Desde el 3 de octubre de 2024, Colombia implementa cambios en la expedición del pasaporte para mayor eficiencia. La Imprenta Nacional asumirá la elaboración desde septiembre de 2025 con asesoramiento portugués. Se introducirá la opción de renovación y actualización en línea para quienes hayan obtenido su pasaporte desde 2017, reduciendo costos significativamente. Las nuevas tarifas oscilan entre $180.000 en Bogotá y 60 euros o 82 dólares en el exterior.
#
# Noticia 1
# El número de internautas en el mundo ha continuado creciendo desde 2005, con un incremento significativo durante la pandemia, especialmente en Colombia donde se espera alcanzar 44 millones en cinco años. Las redes sociales como Facebook y plataformas locales como Chat Bogota han facilitado la interacción entre ciudadanos de diferentes países. En América Latina, Brasil y México son líderes en valorar el socializar libremente. Moderadores en chats online garantizan una experiencia positiva, revisando y eliminando contenido inapropiado. Salas específicas para ciudades como Bogotá permiten a los usuarios conectarse con personas de su mismo país y ciudad, potenciando la posibilidad de encuentros presenciales.
#
# Noticia 2
# El jueves 3 de octubre, la Imprensa Nacional Casa da Moeda de Portugal visitó las instalaciones de la Imprenta Nacional en Colombia tras firmar un memorando de entendimiento para cooperar en la producción y personalización de pasaportes. El acuerdo permitirá a Portugal producir libretas de pasaporte durante 10 años, tras lo cual donará la infraestructura al gobierno colombiano. La Cancillería destaca la experiencia portuguesa en este ámbito, mientras que el modelo incluye capacitación y transferencia de conocimientos para asumir la producción local a partir de septiembre de 2025.
#
# Noticia 3
# El lunes 7 de octubre de 2024, Enel Colombia realizará trabajos de mantenimiento en redes eléctricas que causarán cortes de luz en varios barrios de Bogotá. Los residentes de Fontibón, Teusaquillo, Suba, Usaquén, Ciudad Bolívar, Kennedy, Puente Aranda y Santa Fe se preparan para interrupciones programadas desde las 8 a.m. hasta las 5:30 p.m., afectando áreas específicas en cada barrio. Estos cortes podrían impactar el servicio de agua y drenaje en algunas zonas, y la Alcaldía recomienda a los residentes prepararse con anticipación.
#
# Noticia 4
# La restricción de pico y placa en Bucaramanga sigue vigente, afectando vehículos particulares, motocicletas y taxis. Los automóviles con placas terminadas en 5 o 6 no pueden circular entre las 6:00 a. m. y 8:00 p. m., mientras que los taxis con placas terminadas en 3 o 4 deben evitar el tráfico de 7:00 a. m. a 9:00 p. m. La medida busca reducir la congestión vehicular y mejorar la movilidad, aunque incurre en multas quienes no cumplan.
#
# Noticia 5
# El Establecimiento Público Ambiental (EPA) de Cartagena y Ecopetrol organizaron el evento 'Rumbo a la COP16 por la biodiversidad de nuestro territorio' en Cali, con más de 230 expertos participantes. El director del EPA Cartagena, Mauricio Rodríguez, destacó su importancia para educar sobre la COP16 y la conservación de biodiversidad. Entre las iniciativas compartidas estuvo la estrategia Vigías Rurales de Corpoguajira, que capacita a comunidades locales en la gestión ambiental. El evento también formó parte de "Enrútate por el Ambiente", con metas alineadas al Plan de Desarrollo Distrital de Cartagena. Las implicaciones son significativas para preparar a Colombia y el Caribe para la COP16, que se celebrará en 2024 y busca avanzar en la conservación global de biodiversidad.
#
# Noticia 6
# La Cámara de Representantes aprobó un incremento gradual del recargo dominical y festivo para trabajadores colombianos, que alcanzará el 100% en 2027. El Ministerio de Trabajo celebró la medida, mientras que el Consejo Gremial expresó preocupación sobre los mayores costos para las empresas. Este artículo debe ser discutido aún en el Senado.
#
# Noticia 7
# El sector inmobiliario en Colombia muestra señales de recuperación después de 25 meses consecutivos de caídas, gracias a la reducción de tasas de interés hipotecarias. Guillermo Herrera, presidente de Camacol, destaca este cambio positivo, aunque advierte que aún no se ha superado por completo la crisis. Las ventas de viviendas aumentaron un 5,7% en agosto, impulsadas por una disminución en los desistimientos y el apoyo del sector privado y subsidios gubernamentales. No obstante, persisten retos como la lenta rotación de inventarios en vivienda de interés social y la pérdida de empleos en construcción.
#
# Noticia 8
# Las lluvias han incrementado en varias regiones de Colombia, según pronósticos meteorológicos. El meteorólogo Max Henríquez ha reportado precipitaciones en ciudades como Bogotá y Cali, mientras que el Ideam prevé aumentos de lluvia para octubre en gran parte del país. Estas precipitaciones son cruciales para la recuperación de la selva amazónica y los embalses en Bogotá. El aumento de las lluvias podría beneficiar a regiones como la Andina y el Caribe, pero también afectará negativamente a áreas como la Orinoquía y gran parte de la Amazonía.
#
# Noticia 9
# La sequía que afectó Bogotá y otras regiones del país durante meses ha sido seguida por fuertes lluvias, causando preocupación entre la población y agricultores debido a la pérdida de cultivos. El Tolima registró incendios forestales que quemaron más de 8.000 hectáreas. Sin embargo, desde el 1° de octubre se espera un aumento en las precipitaciones en Bogotá, con lluvias moderadas y hasta fuertes aguaceros en los próximos días. Las autoridades han reportado emergencias por árboles caídos e inundaciones en varias localidades de la capital.
#
# Noticia 10
# La maratón, un desafío físico y mental, se prepara a ser celebrada por primera vez en Bogotá el 1 de diciembre. Juan Carlos González, director de VChallenges 42, destaca la importancia de una preparación adecuada que incluye entrenamiento de 10 a 16 semanas. Aunque considera que correr una maratón es un logro excepcional, subraya que Bogotá no tiene impedimentos físicos para albergar esta competencia. González también destaca la relevancia simbólica y cultural de la maratón en el atletismo mundial.
#
# Noticia 11
# Centauro Capital y Natanor XXI notificaron al gobierno colombiano una posible demanda internacional por la intervención forzosa de la EPS Sanitas, argumentando expropiación indirecta y incumplimiento de tratados. El Ministerio de Comercio y la Agencia de Defensa Jurídica del Estado se preparan para potenciales conciliaciones antes de un arbitraje internacional. Si no hay acuerdo, el proceso podría durar hasta cinco años. Un precedente similar ocurrió con Electricaribe en 2016, donde Colombia ganó sin pagar indemnizaciones.
#
# Noticia 12
# El Banco Mundial ha revisado sus proyecciones de crecimiento económico para Colombia y América Latina. Para 2024, espera un crecimiento del 1,5%, un aumento de 0,2 puntos porcentuales respecto a junio. Sin embargo, para 2025 y 2026, las estimaciones se han reducido. El Banco Mundial atribuye estos bajos pronósticos a obstáculos estructurales y desigualdad persistente en la región. La organización sugiere que los países deben aprovechar el impulso actual para implementar reformas estructurales que fomenten el crecimiento sostenible, como modernizar sistemas tributarios y recaudatorios.
#
# Noticia 13
# El proceso para obtener pasaportes en Colombia ha cambiado a partir del 3 de octubre, permitiendo la renovación y expedición por vía virtual. La Imprenta Nacional transicionará con Thomas Greg & Sons hasta septiembre de 2025. El costo disminuirá a $180.000 en Bogotá, mientras que en otros países será de 60 euros o 82 dólares. Algunos grupos, como personas del Sisbén niveles 1 y 2, podrán obtenerlo gratis si cumplen con ciertos requisitos.
#
# Noticia 14
# La Empresa de Acueducto y Alcantarillado de Bogotá (EAAB) ha anunciado un nuevo turno de racionamiento de agua para el 2 de octubre en varios sectores de Bogotá y sus alrededores, afectando principalmente a barrios como Bosa, Ciudad Bolívar, Kennedy, Puente Aranda y Tunjuelito. Esta medida busca preservar los niveles de los embalses que abastecen la ciudad para garantizar el suministro sostenible tanto en Bogotá como en las poblaciones vecinas. La EAAB ha compartido recomendaciones para un uso responsable del agua durante estos días.
#
# Las implicaciones a corto plazo incluyen restricciones significativas en el consumo de agua en los barrios afectados, lo que puede impactar en la vida cotidiana y servicios básicos. A largo plazo, se espera mejorar la eficiencia en el uso del recurso hídrico y asegurar la sostenibilidad del suministro.
#
# Noticia 15
# El sexto ciclo de negociaciones entre el Gobierno y las disidencias de las Farc-EP, lideradas por Calarcá, tiene fecha definida para esta semana en Bogotá. Camilo González Posso, jefe de la delegación gubernamental, confirmó que la plenaria se realizará después de reuniones preliminares con los bloques involucrados. Se discute la posibilidad de extender el cese del fuego hasta el 15 de octubre y el papel de Rafaela Cortés, gobernadora del Meta, como facilitadora en el proceso. Las conversaciones buscan avanzar hacia acuerdos que beneficien a las comunidades y se evalúa la situación de enfrentamientos violentos en zonas afectadas.
#
# Noticia 16
# El inicio de octubre en Bogotá ha estado caracterizado por bajas temperaturas y neblina, lo cual podría afectar el tráfico aéreo. La Aeronáutica Civil advirtió que estas condiciones podrían causar demoras en los vuelos del Aeropuerto El Dorado. Además, 116 colombianos repatriados desde Líbano aún no han llegado debido a las mismas condiciones climáticas que están retrasando el itinerario de su vuelo.
#
# Noticia 17
# El Servicio Administrativo de Identificación, Migración y Extranjería de Venezuela (Saime) informó que ciudadanos que tramitaron pasaportes en consulados cerrados deben recogerlos en Caracas. Latam Colombia anunció que rechazará a pasajeros venezolanos con pasaporte vencido, obligándolos a obtener un "Documento de Viaje" o viajar con doble nacionalidad. Estas medidas podrían afectar la movilidad y los trámites de miles de venezolanos en el exterior.
#
# Noticia 18
# El Ministro de Comercio, Industria y Turismo, Luis Carlos Reyes, solicitó la renuncia al gerente de Fontur, Álvaro Edgar Balcázar. Balcázar asumió el cargo en septiembre de 2022 bajo el gobierno de Gustavo Petro. Su renuncia entrará en vigor el 9 de octubre. Anteriormente, Balcázar ocupó posiciones clave en el DNP y Fonade. Fontur, bajo su dirección, aprobó 202 proyectos turísticos en 2023, invirtiendo más de $400 mil millones en promoción y fortalecimiento del sector.
#
# Noticia 19
# El lunes 14 de octubre de 2024, Bogotá implementará pico y placa regional para el ingreso a la ciudad durante el puente festivo. Los vehículos con placas terminadas en números pares podrán circular entre las 12:00 p. m. y 4:00 p. m., mientras que los impares lo harán entre las 4:00 p. m. y 8:00 p. m. La medida aplica a nueve corredores viales específicos. Residentes y visitantes deben programar sus viajes según el último dígito de su placa para evitar inconvenientes.
#
# Noticia 20
# El plan éxodo para el puente festivo de octubre en Bogotá comienza este sábado con un pico y placa voluntario. La Secretaría de Movilidad implementará restricciones horarias basadas en los números finales de las placas, permitiendo la circulación de vehículos con placas pares o impares en diferentes franjas. Estas medidas buscan facilitar el traslado de ciudadanos que salen de la capital durante el 'Día de la Raza'.
#
# Noticia 21
# El martes 1 de octubre de 2024, Bogotá implementa medidas de racionamiento de agua que han llevado al cierre temporal de varios parques y espacios deportivos en Usaquén y Suba. La Alcaldía y la EAAB mantienen turnos diarios de racionamiento en nueve zonas afectando a la capital y municipios aledanos desde el 29 de septiembre. Estas medidas buscan proteger la integridad física, contribuir a la conservación del agua y mitigar las consecuencias de la escasez.
#
# Noticia 22
# Valery Bujato, una creadora de contenido colombiana radicada en Estados Unidos, comparte su experiencia diaria como influencer y sus videos sobre misterios y rutina. Juan Giraldo, otro creador de contenido colombiano en Boston, ofrece consejos sobre vida crediticia y aprendizaje del inglés. Ambos destacan la soledad y el desafío de adaptarse a un nuevo país, mientras buscan prosperar en el mundo digital.
#
# Noticia 29
# Xiaomi ha lanzado en Colombia su nueva Serie Xiaomi 14T, que incluye dos dispositivos con cámaras de alta calidad y lentes profesionales de Leica. Estos smartphones ofrecen una experiencia visual impresionante y funciones avanzadas como el modo película y la inteligencia artificial para mejorar la productividad y la creatividad. El Xiaomi 14T Pro estará disponible a partir del 10 de octubre por $3'499.900, mientras que el Xiaomi 14T costará $2'799.900. Ambos modelos incluyen baterías de alta capacidad y tecnologías de carga rápida.
#
# Noticia 30
# Desde el 3 de octubre de 2024, Colombia implementa cambios en la expedición del pasaporte para mayor eficiencia. La Imprenta Nacional asumirá la elaboración desde septiembre de 2025 con asesoramiento portugués. Se introducirá la opción de renovación y actualización en línea para quienes hayan obtenido su pasaporte desde 2017, reduciendo costos significativamente. Las nuevas tarifas oscilan entre $180.000 en Bogotá y 60 euros o 82 dólares en el exterior.

# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate
)

def get_topic_in_cluster(news: str, model_name: str = "qwen2.5:7b") -> str:

    llm_ollama = ChatOllama(
        model=model_name,
        temperature=0.1,
        num_predict=4096,
        num_ctx=16000,
        keep_alive=0
    )

    prompt_summarization = ChatPromptTemplate(
        [
            SystemMessagePromptTemplate.from_template(
                """Eres un asistente especializado en análisis de noticias y clustering semántico. Tu tarea es ayudar a identificar temas, """
                """palabras clave y subtemas dentro de grupos de resúmenes de noticias. Analizas los patrones comunes en los eventos, """
                """lugares, personas y palabras clave para proporcionar una descripción clara y precisa del tema principal de cada grupo """
                """de noticias. Además, eres capaz de detectar subtemas o enfoques recurrentes que puedan enriquecer el análisis."""
            ),
            HumanMessagePromptTemplate.from_template(
                """Los siguientes son resúmenes de noticias que han sido agrupados en un clúster debido a su similitud semántica. """
                """Tu tarea es analizar estos resúmenes y proporcionar una caracterización general del tema principal del clúster. """
                """Identifica patrones comunes en los eventos, lugares, personas y palabras clave mencionadas, y determina un título o """
                """categoría representativa que capture la esencia del clúster."""
                """Además, destaca si hay algún subtema relevante o recurrente que ayude a entender mejor el enfoque de las noticias en """
                """este grupo. Asegúrate de que la descripción sea clara y precisa para que refleje el contenido general de las noticias."""
                """Resúmenes de noticias en el clúster: {news}"""
                """Salida esperada:
                    Tema principal: Una breve descripción del tema general del clúster.
                    Palabras clave: Lista de palabras clave relevantes.
                    Subtemas (si los hay): Cualquier subtema adicional que aparezca en varios resúmenes.
                    Título sugerido: Un título breve que represente el clúster."""
                )
        ]
    )

    llm_chain = prompt_summarization | llm_ollama | StrOutputParser()

    return llm_chain.invoke({"news": news})

# %%
label_cluster = 1
print(f"Cluster con label: {label_cluster}\nNoticias de la muestra:\n")
news_summary = get_text_sample_by_cluster(label_cluster, 5)
print(get_topic_in_cluster(news_summary))
# Out:
# Cluster con label: 1
# Noticias de la muestra:
#
# Noticia 1
